# %%
import pandas as pd

# Load the data
df = pd.read_csv("football_salaries.csv")

# Columns that must NOT be zero
cols_to_check = [
    "age",
    "total_value",
    "avg_year",
    "total_guaranteed",
    "fully_guaranteed"
]

# List to store indices of rows we want to keep
rows_to_keep = []

# Loop through each row by numeric index
for i in range(len(df)):
    row = df.iloc[i]
    
    keep = True   # assume row is good
    
    # Check every required column
    for col in cols_to_check:
        if row[col] == 0:
            keep = False
            break  # no need to continue checking
    
    if keep:
        rows_to_keep.append(i)

# Build cleaned DataFrame from rows we kept
clean_df = df.loc[rows_to_keep]

# Save result
clean_df.to_csv("football_salaries_no_zero.csv", index=False)

print(clean_df)
# Out:
#             position          player      team  age  total_value  avg_year  \
# 0       right-tackle     Trent Brown   Raiders   26     66000000  16500000
# 1       right-tackle   Ja’Wuan James   Broncos   27     51000000  12750000
# 2       right-tackle    Lane Johnson    Eagles   29     56250000  11250000
# 3       right-tackle    Ricky Wagner     Lions   30     47500000   9500000
# 4       right-tackle  Rob Havenstein      Rams   26     32500000   8125000
# ...              ...             ...       ...  ...          ...       ...
# 5451  defensive-back     Kenny Moore     Colts   24      1667500    555833
# 5453  defensive-back   Kavon Frazier   Cowboys   26      2170356    542589
# 5499  defensive-back     A.J. Howard  Patriots   24       505000    505000
# 5500  defensive-back     Duke Thomas   Vikings   25       500000    500000
# 5501  defensive-back    Rico Gafford   Raiders   23       995600    497800
#
#       total_guaranteed  fully_guaranteed free_agency
# 0             36250000          36250000    2023 UFA
# 1             32000000          27000000    2023 UFA
# 2             35500000          20862242   2022 Void
# 3             29500000          17500000    2022 UFA
# 4             16226365           9976365    2023 UFA
# ...                ...               ...         ...
# 5451              5000              5000    2020 RFA
# 5453            100356            100356    2020 UFA
# 5499              5000              5000   2020 ERFA
# 5500              5000              2500   2020 ERFA
# 5501             20600             20600   2020 ERFA
#
# [3223 rows x 9 columns]

# %%
import pandas as pd

df = pd.read_csv("football_salaries_no_zero.csv")

# Remove duplicate players (keep first entry)
clean_df = df.drop_duplicates(subset="player", keep="first")

print(clean_df)
# Out:
#            position           player       team  age  total_value  avg_year  \
# 0      right-tackle      Trent Brown    Raiders   26     66000000  16500000
# 1      right-tackle    Ja’Wuan James    Broncos   27     51000000  12750000
# 2      right-tackle     Lane Johnson     Eagles   29     56250000  11250000
# 3      right-tackle     Ricky Wagner      Lions   30     47500000   9500000
# 4      right-tackle   Rob Havenstein       Rams   26     32500000   8125000
# ...             ...              ...        ...  ...          ...       ...
# 3072  wide-receiver  Trent Sherfield  Cardinals   23      1720000    573333
# 3073  wide-receiver    Vyncint Smith     Texans   23      1720000    573333
# 3074  wide-receiver  Derrick Willies     Browns   25      1712500    570833
# 3100  wide-receiver      Austin Carr     Saints   26      1672500    557500
# 3109  wide-receiver  Kendrick Bourne      49ers   24      1670000    556667
#
#       total_guaranteed  fully_guaranteed free_agency
# 0             36250000          36250000    2023 UFA
# 1             32000000          27000000    2023 UFA
# 2             35500000          20862242   2022 Void
# 3             29500000          17500000    2022 UFA
# 4             16226365           9976365    2023 UFA
# ...                ...               ...         ...
# 3072             10000             10000    2021 RFA
# 3073             35000             35000    2021 RFA
# 3074              2500              2500    2021 RFA
# 3100             30000             30000    2020 RFA
# 3109             25000             25000    2020 RFA
#
# [1663 rows x 9 columns]

# %%
clean_df.to_csv("football_salaries_cleaned.csv", index=False)

# %%
import pandas as pd

df = pd.read_csv("football_salaries_cleaned.csv")

# Group players by position
grouped = df.groupby("position")

for pos, group in grouped:
    print(f"Position: {pos}")
    print(group[["player", "position"]])
    print("-----")
# Out:
# Position: 3-4-defensive-end
#                   player           position
# 57             J.J. Watt  3-4-defensive-end
# 58         Jurrell Casey  3-4-defensive-end
# 69         Stephon Tuitt  3-4-defensive-end
# 70           Akiem Hicks  3-4-defensive-end
# 71      Michael Brockers  3-4-defensive-end
# 72      Brandon Williams  3-4-defensive-end
# 73       Cameron Heyward  3-4-defensive-end
# 74          Mike Daniels  3-4-defensive-end
# 75           Derek Wolfe  3-4-defensive-end
# 76        Henry Anderson  3-4-defensive-end
# 94     Matthew Ioannidis  3-4-defensive-end
# 95          DaQuan Jones  3-4-defensive-end
# 96      Leonard Williams  3-4-defensive-end
# 97       Angelo Blackson  3-4-defensive-end
# 117      Jeffery Simmons  3-4-defensive-end
# 118       Jonathan Allen  3-4-defensive-end
# 119         Tyson Alualu  3-4-defensive-end
# 120            Zach Kerr  3-4-defensive-end
# 121           Carl Davis  3-4-defensive-end
# 154           Josh Mauro  3-4-defensive-end
# 155      DeMarcus Walker  3-4-defensive-end
# 156          Brent Urban  3-4-defensive-end
# 157     Dalvin Tomlinson  3-4-defensive-end
# 158            B.J. Hill  3-4-defensive-end
# 159          Adam Gotsis  3-4-defensive-end
# 215      Nathan Shepherd  3-4-defensive-end
# 216  Rakeem Nunez-Roches  3-4-defensive-end
# 217    Nicholas Williams  3-4-defensive-end
# 218        Chris Wormley  3-4-defensive-end
# 219     Jonathan Bullard  3-4-defensive-end
# 276     Montravius Adams  3-4-defensive-end
# 277        Tarell Basham  3-4-defensive-end
# 278  John Franklin-Myers  3-4-defensive-end
# 331        Tyrone Holmes  3-4-defensive-end
# 332       Carlos Watkins  3-4-defensive-end
# 333      Charles Omenihu  3-4-defensive-end
# 385          RJ McIntosh  3-4-defensive-end
# 386        Bilal Nichols  3-4-defensive-end
# 387         Willie Henry  3-4-defensive-end
# 388           Dean Lowry  3-4-defensive-end
# 426         Duke Ejiofor  3-4-defensive-end
# 427   Folorunso Fatukasi  3-4-defensive-end
# 474         Tanzel Smart  3-4-defensive-end
# 475          Zach Sieler  3-4-defensive-end
# 476         Chuck Harris  3-4-defensive-end
# 520       Michael Onuoha  3-4-defensive-end
# 521          Nate Harvey  3-4-defensive-end
# 522      Immanuel Turner  3-4-defensive-end
# 523        Amani Bledsoe  3-4-defensive-end
# 524          Jamal Davis  3-4-defensive-end
# 525         Markus Jones  3-4-defensive-end
# 561  Trumaine Johnson  defensive-back
# 562     Xavier Rhodes  defensive-back
# 563  Patrick Peterson  defensive-back
# 564       Kyle Fuller  defensive-back
# 565    Landon Collins  defensive-back
# 623   Stephon Gilmore  defensive-back
# 624   Janoris Jenkins  defensive-back
# 710   Dre Kirkpatrick  defensive-back
# -----
# Position: defensive-line
#                 player        position
# 30        Aaron Donald  defensive-line
# 43   Demarcus Lawrence  defensive-line
# 44         Frank Clark  defensive-line
# 45        Trey Flowers  defensive-line
# 46        Fletcher Cox  defensive-line
# 47            Dee Ford  defensive-line
# 61      Olivier Vernon  defensive-line
# 62      Chandler Jones  defensive-line
# 63         Geno Atkins  defensive-line
# 64        Kawann Short  defensive-line
# 65       Melvin Ingram  defensive-line
# 82   Jason Pierre-Paul  defensive-line
# 83     Calais Campbell  defensive-line
# 84     Everson Griffen  defensive-line
# 85     Danielle Hunter  defensive-line
# 86       Carlos Dunlap  defensive-line
# 108     Brandon Graham  defensive-line
# 109  Dante Fowler, Jr.  defensive-line
# 132     Cameron Jordan  defensive-line
# 133       Jerry Hughes  defensive-line
# 134      Eddie Goldman  defensive-line
# -----
# Position: fullback
#                player  position
# 670     Kyle Juszczyk  fullback
# 671   Patrick DiMarco  fullback
# 672    Jamize Olawale  fullback
# 673     James Develin  fullback
# 674     Roosevelt Nix  fullback
# 740       Keith Smith  fullback
# 741      Nick Bellore  fullback
# 742         Zach Line  fullback
# 743  Cullen Gillaspia  fullback
# 822       Nick Bawden  fullback
# 823     Andy Janovich  fullback
# 824        Derek Watt  fullback
# 825  Khari Blasingame  fullback
# 883      George Aston  fullback
# -----
# Position: inside-linebacker
#                     player           position
# 907             David Mayo  inside-linebacker
# 960        Zach Cunningham  inside-linebacker
# 961       Brandon Marshall  inside-linebacker
# 962            Fred Warner  inside-linebacker
# 1004          Kevin Minter  inside-linebacker
# 1005             Mike Hull  inside-linebacker
# 1006            Oren Burks  inside-linebacker
# 1047           Bryce Hager  inside-linebacker
# 1048          Josey Jewell  inside-linebacker
# 1049      Joel Iyiegbuniwe  inside-linebacker
# 1050           Kenny Young  inside-linebacker
# 1051          Joe Schobert  inside-linebacker
# 1097          B.J. Goodson  inside-linebacker
# 1098       Nick Kwiatkoski  inside-linebacker
# 1128         Cameron Smith  inside-linebacker
# 1129        D’Andre Walker  inside-linebacker
# 1130           Micah Kiser  inside-linebacker
# 1162  Jermaine Carter, Jr.  inside-linebacker
# 1163        David Long Jr.  inside-linebacker
# 1164           Jayon Brown  inside-linebacker
# 1165    Anthony Walker Jr.  inside-linebacker
# 1166           Marquel Lee  inside-linebacker
# 1201         Christian Sam  inside-linebacker
# 1202   Shaun Dion Hamilton  inside-linebacker
# 1203            Jack Cichy  inside-linebacker
# 1220      Keishawn Bierria  inside-linebacker
# 1257     Kentrell Brothers  inside-linebacker
# 1258         Matthew Adams  inside-linebacker
# 1259         Devante Downs  inside-linebacker
# 1260        Tanner Vallejo  inside-linebacker
# 1261           Andre Smith  inside-linebacker
# 1262   Josh Harvey-Clemons  inside-linebacker
# 1293        Blake Martinez  inside-linebacker
# 1294       Elandon Roberts  inside-linebacker
# 1295      Tyler Matakevich  inside-linebacker
# 1296            Malik Reed  inside-linebacker
# 1325              BJ Blunt  inside-linebacker
# 1326          Tre Crawford  inside-linebacker
# 1327        Josiah Tauaefa  inside-linebacker
# 1328            Joe Dineen  inside-linebacker
# 1329            Drew Lewis  inside-linebacker
# 1330           Otaro Alaka  inside-linebacker
# 1331       Jordan Kunaszyk  inside-linebacker
# 1355          Te’von Coney  inside-linebacker
# 1356           Josh Watson  inside-linebacker
# 1357          Dante Booker  inside-linebacker
# 1358         Curtis Bolton  inside-linebacker
# 1359          Randy Ramsey  inside-linebacker
# 1381              EJ Ejiya  inside-linebacker
# 1382         Silas Stewart  inside-linebacker
# 1383             Nate Hall  inside-linebacker
# 1384       Justin Phillips  inside-linebacker
# 1385    Del’Shawn Phillips  inside-linebacker
# 1425          Sharif Finch  inside-linebacker
# 1426             Tae Davis  inside-linebacker
# 1437           Chris Board  inside-linebacker
# 1438           Zeke Turner  inside-linebacker
# 1469            Dylan Cole  inside-linebacker
# 1470           Chase Allen  inside-linebacker
# -----
# Position: kicker
#                  player position
# 599       Justin Tucker   kicker
# 600         Graham Gano   kicker
# 601  Stephen Gostkowski   kicker
# 658       Chris Boswell   kicker
# 659            Wil Lutz   kicker
# 660        Mason Crosby   kicker
# 661         Ryan Succop   kicker
# 662      Adam Vinatieri   kicker
# 726         Jason Myers   kicker
# 727         Matt Prater   kicker
# 728          Josh Lambo   kicker
# 729     Brandon McManus   kicker
# 730    Stephen Hauschka   kicker
# 731      Dustin Hopkins   kicker
# 811  Chandler Catanzaro   kicker
# 812       Greg Zuerlein   kicker
# 813       Randy Bullock   kicker
# 814        Cairo Santos   kicker
# 815          Dan Bailey   kicker
# 816            Matt Gay   kicker
# 877       Jason Sanders   kicker
# 924         Matt Wright   kicker
# 925    Chase McLaughlin   kicker
# 926        Eddy Pineiro   kicker
# -----
# Position: left-guard
#                   player    position
# 135       Andrew Norwell  left-guard
# 170          Cordy Glenn  left-guard
# 171      Kelechi Osemele  left-guard
# 172       Rodger Saffold  left-guard
# 173           Ali Marpet  left-guard
# 174         Joel Bitonio  left-guard
# 229         Ronald Leary  left-guard
# 230          Zach Fulton  left-guard
# 231         Billy Turner  left-guard
# 232       Quenton Nelson  left-guard
# 233        Isaac Seumalo  left-guard
# 234          Nick Easton  left-guard
# 235      Laken Tomlinson  left-guard
# 289          Lane Taylor  left-guard
# 290      James Carpenter  left-guard
# 291         Clint Boling  left-guard
# 292         Ramon Foster  left-guard
# 293           Evan Smith  left-guard
# 294         Frank Ragnow  left-guard
# 295          Andrus Peat  left-guard
# 296          Mike Person  left-guard
# 344          Mike Iupati  left-guard
# 345        Quinton Spain  left-guard
# 346           Max Garcia  left-guard
# 347       Austin Corbett  left-guard
# 348            Eric Kush  left-guard
# 349       Will Hernandez  left-guard
# 350        James Daniels  left-guard
# 351       Kevin Pamphile  left-guard
# 396           Chris Reed  left-guard
# 397      Connor Williams  left-guard
# 398     Vladimir Ducasse  left-guard
# 399          Ethan Pocic  left-guard
# 441           Ted Larsen  left-guard
# 442           Dan Feeney  left-guard
# 443       Bryan Witzmann  left-guard
# 444        Dakota Dozier  left-guard
# 445       Greg Van Roten  left-guard
# 494     Xavier Su’a-Filo  left-guard
# 495           Joe Thuney  left-guard
# 541           Alex Lewis  left-guard
# 542   Scott Quessenberry  left-guard
# 543         Wyatt Teller  left-guard
# 544      Kahlil McKenzie  left-guard
# 545             Joe Dahl  left-guard
# 596  Christian Westerman  left-guard
# 597    Keaton Sutherland  left-guard
# 598       Demetrius Knox  left-guard
# 651        Lester Cotton  left-guard
# 652          John Leglue  left-guard
# 653            Alex Bars  left-guard
# 654       Marquez Tucker  left-guard
# 655     Bunchy Stallings  left-guard
# 656       Larry Williams  left-guard
# 657      Austin Droogsma  left-guard
# 808           Nico Falah  left-guard
# 809        Brendan Mahon  left-guard
# 810           Nick Gates  left-guard
# 876        Aaron Stinnie  left-guard
# -----
# Position: left-tackle
#                 player     position
# 141       Taylor Lewan  left-tackle
# 190        Nate Solder  left-tackle
# 191      Jake Matthews  left-tackle
# 192      Donovan Smith  left-tackle
# 193      Russell Okung  left-tackle
# ...                ...          ...
# 865       Tyler Roemer  left-tackle
# 969   Desmond Harrison  left-tackle
# 1014        Alex Light  left-tackle
# 1015   Aviante Collins  left-tackle
# 1099       Dan Skipper  left-tackle
#
# [64 rows x 2 columns]
# -----
# Position: linebacker
#                 player    position
# 59         C.J. Mosley  linebacker
# 60        Anthony Barr  linebacker
# 77      Kwon Alexander  linebacker
# 78        Luke Kuechly  linebacker
# 98      Justin Houston  linebacker
# ...                ...         ...
# 869      Uchenna Nwosu  linebacker
# 870        Kyle Wilber  linebacker
# 918   Raekwon McMillan  linebacker
# 919        Deion Jones  linebacker
# 1643   Nicholas Morrow  linebacker
#
# [75 rows x 2 columns]
# -----
# Position: long-snapper
#                player      position
# 437     Jake McQuaide  long-snapper
# 438     Beau Brinkley  long-snapper
# 439      Clark Harris  long-snapper
# 440       Kyle Nelson  long-snapper
# 487     Nick Sundberg  long-snapper
# 488       Zak DeOssie  long-snapper
# 489      LP Ladouceur  long-snapper
# 490      Don Muhlbach  long-snapper
# 491       John Denney  long-snapper
# 492        Morgan Cox  long-snapper
# 493        Mike Windt  long-snapper
# 535    Jeffrey Jansen  long-snapper
# 536       Joe Cardona  long-snapper
# 537    Andrew DePaola  long-snapper
# 538  Charley Hughlett  long-snapper
# 539      Aaron Brewer  long-snapper
# 540   Kevin McDermott  long-snapper
# 592         Jon Weeks  long-snapper
# 593     Reid Ferguson  long-snapper
# 594  James Winchester  long-snapper
# 595       Josh Harris  long-snapper
# 650    Hunter Bradley  long-snapper
# 724       John Wirtel  long-snapper
# 725        Kyle Vasey  long-snapper
# -----
# Position: punter
#                 player position
# 446    Thomas Morstead   punter
# 447      Johnny Hekker   punter
# 496         Sam Martin   punter
# 497           Sam Koch   punter
# 498         Brett Kern   punter
# 499        Matt Bosher   punter
# 500   Britton Colquitt   punter
# 501     Bradley Pinion   punter
# 547        Kevin Huber   punter
# 548    Michael Palardy   punter
# 549    Dustin Colquitt   punter
# 550           Andy Lee   punter
# 551       Jordan Berry   punter
# 552      Pat O’Donnell   punter
# 553          Tress Way   punter
# 611         Ryan Allen   punter
# 612   Mitch Wishnowsky   punter
# 613    Michael Dickson   punter
# 614           JK Scott   punter
# 615    Johnny Townsend   punter
# 694        Logan Cooke   punter
# 695        Riley Dixon   punter
# 696    Lachlan Edwards   punter
# 697       Jamie Gillan   punter
# 698            AJ Cole   punter
# 762       Kaare Vedvik   punter
# 843      Trevor Daniel   punter
# 844     Austin Barnard   punter
# 845  Rigoberto Sanchez   punter
# 846         Matt Haack   punter
# 902   Cameron Johnston   punter
# 903        Cory Carter   punter
# -----
# Position: quarterback
#                   player     position
# 610       Russell Wilson  quarterback
# 687   Ben Roethlisberger  quarterback
# 688        Aaron Rodgers  quarterback
# 689            Matt Ryan  quarterback
# 690         Kirk Cousins  quarterback
# ...                  ...          ...
# 1352         Eric Dungey  quarterback
# 1353      Wilton Speight  quarterback
# 1377           Tim Boyle  quarterback
# 1378         Cooper Rush  quarterback
# 1379         Taysom Hill  quarterback
#
# [78 rows x 2 columns]
# -----
# Position: right-guard
#                        player     position
# 113               Zack Martin  right-guard
# 114             Kevin Zeitler  right-guard
# 115               Trai Turner  right-guard
# 143              Gabe Jackson  right-guard
# 144            David DeCastro  right-guard
# 145             Marshal Yanda  right-guard
# 146               Justin Pugh  right-guard
# 147           Shaquille Mason  right-guard
# 148             Larry Warford  right-guard
# 198   Laurent Duvernay-Tardif  right-guard
# 199            Brandon Brooks  right-guard
# 200             Brian Winters  right-guard
# 201                 Kyle Long  right-guard
# 202               Jamon Brown  right-guard
# 262               John Miller  right-guard
# 263            Mark Glowinski  right-guard
# 264           Brandon Scherff  right-guard
# 265                Josh Kline  right-guard
# 266                   AJ Cann  right-guard
# 321               J.R. Sweezy  right-guard
# 322            Senio Kelemete  right-guard
# 323             Jon Feliciano  right-guard
# 324             Ereck Flowers  right-guard
# 325                 DJ Fluker  right-guard
# 326         Michael Schofield  right-guard
# 375             Kenny Wiggins  right-guard
# 376              Mike Remmers  right-guard
# 377            Joshua Garnett  right-guard
# 415              Braden Smith  right-guard
# 416              Forrest Lamp  right-guard
# 417               Tom Compton  right-guard
# 418              Oday Aboushi  right-guard
# 419                Nate Davis  right-guard
# 420              Jordan Devey  right-guard
# 464              Earl Watford  right-guard
# 465             Andrew Donnal  right-guard
# 466                Alex Cappa  right-guard
# 517              Cole Madison  right-guard
# 576             Danny Isidora  right-guard
# 577            Caleb Benenoch  right-guard
# 578                Matt Pryor  right-guard
# 579                  Joe Haeg  right-guard
# 635                Rod Taylor  right-guard
# 636            Wes Schweitzer  right-guard
# 715             Austin Blythe  right-guard
# 787              Fred Johnson  right-guard
# 788          Malcolm Pridgeon  right-guard
# 789              O’Shea Dugas  right-guard
# 790          Larry Allen, Jr.  right-guard
# 791            Blake Blackmar  right-guard
# 792                Joe Lowery  right-guard
# 866             Ross Reynolds  right-guard
# 915              Ike Boettger  right-guard
# 1016           Brandon Greene  right-guard
# 1017             Kitt O’Brien  right-guard
# -----
# Position: right-tackle
#                  player      position
# 0           Trent Brown  right-tackle
# 1         Ja’Wuan James  right-tackle
# 2          Lane Johnson  right-tackle
# 3          Ricky Wagner  right-tackle
# 4        Rob Havenstein  right-tackle
# 5          Morgan Moses  right-tackle
# 6          Bobby Massie  right-tackle
# 7         La’el Collins  right-tackle
# 8         Chris Hubbard  right-tackle
# 9          Bryan Bulaga  right-tackle
# 10    Mitchell Schwartz  right-tackle
# 11        Marcus Cannon  right-tackle
# 12       Daryl Williams  right-tackle
# 13       Marcus Gilbert  right-tackle
# 14          Cody Conway  right-tackle
# 15         Demar Dotson  right-tackle
# 16           Bobby Hart  right-tackle
# 17         Ty Sambrailo  right-tackle
# 18      Mike McGlinchey  right-tackle
# 19          James Hurst  right-tackle
# 20   Seantrel Henderson  right-tackle
# 21         Jack Conklin  right-tackle
# 25         Kendall Lamm  right-tackle
# 26         Ryan Ramczyk  right-tackle
# 27        Germain Ifedi  right-tackle
# 28        Jawaan Taylor  right-tackle
# 29        Denzelle Good  right-tackle
# 38         Dennis Kelly  right-tackle
# 39          Brent Qvale  right-tackle
# 40        Max Scharping  right-tackle
# 41        Brian O’Neill  right-tackle
# 42         Taylor Moton  right-tackle
# 52       Brandon Parker  right-tackle
# 53        J’Marcus Webb  right-tackle
# 54       Cedric Ogbuehi  right-tackle
# 55      Martinas Rankin  right-tackle
# 56        Orlando Brown  right-tackle
# 92       Le’Raven Clark  right-tackle
# 93      Will Richardson  right-tackle
# 116       Brandon Shell  right-tackle
# 152     Conor McDermott  right-tackle
# 153         Andre James  right-tackle
# 210      Patrick Mekari  right-tackle
# 211     Tyree St. Louis  right-tackle
# 212       William Sweet  right-tackle
# 213          Tariq Cole  right-tackle
# 214      Lukayus McNeil  right-tackle
# 273           A.T. Hall  right-tackle
# 274        Quinn Bailey  right-tackle
# 275        Derrick Puni  right-tackle
# 383           Matt Gono  right-tackle
# 384        Chad Wheeler  right-tackle
# -----
# Position: running-back
#                player      position
# 616       Todd Gurley  running-back
# 699      Le’Veon Bell  running-back
# 700     David Johnson  running-back
# 701   Devonta Freeman  running-back
# 702      LeSean McCoy  running-back
# ...               ...           ...
# 1532       Mike Boone  running-back
# 1536     Justin Davis  running-back
# 1537    Corey Clement  running-back
# 1538    Austin Ekeler  running-back
# 1539      Matt Breida  running-back
#
# [105 rows x 2 columns]
# -----
# Position: safety
#                  player position
# 546      Tyrann Mathieu   safety
# 605         Earl Thomas   safety
# 606        Reshad Jones   safety
# 607     Lamarcus Joyner   safety
# 608      Harrison Smith   safety
# ...                 ...      ...
# 1547  Trayvon Henderson   safety
# 1548       Raven Greene   safety
# 1569       Jamal Carter   safety
# 1570      Kavon Frazier   safety
# 1594        A.J. Howard   safety
#
# [145 rows x 2 columns]
# -----
# Position: tight-end
#                player   position
# 140      Jimmy Graham  tight-end
# 179      Travis Kelce  tight-end
# 180       Jordan Reed  tight-end
# 181        Greg Olsen  tight-end
# 182         Zach Ertz  tight-end
# ...               ...        ...
# 1387      Sean Culkin  tight-end
# 1388  Jacob Hollister  tight-end
# 1389    Cethan Carter  tight-end
# 1439     Marcus Baugh  tight-end
# 1440     Cedrick Lang  tight-end
#
# [111 rows x 2 columns]
# -----
# Position: wide-receiver
#                   player       position
# 602   Odell Beckham, Jr.  wide-receiver
# 663        Antonio Brown  wide-receiver
# 664           Mike Evans  wide-receiver
# 665      DeAndre Hopkins  wide-receiver
# 666        Brandin Cooks  wide-receiver
# ...                  ...            ...
# 1658     Trent Sherfield  wide-receiver
# 1659       Vyncint Smith  wide-receiver
# 1660     Derrick Willies  wide-receiver
# 1661         Austin Carr  wide-receiver
# 1662     Kendrick Bourne  wide-receiver
#
# [193 rows x 2 columns]
# -----

# %%
import pandas as pd

# Load the data
df = pd.read_csv("football_salaries_cleaned.csv")

# Replace all linebacker variants with "Linebacker"
df["position"] = df["position"].replace(
    [
        "inside-linebacker",
        "3-4-outside-linebacker",
        "4-3-outside-linebacker"
    ],
    "linebacker"
)

# Confirm the changes
print(df["position"].unique())

# (Optional) Save updated file
df.to_csv("football_salaries_updated.csv", index=False)
# Out:
# ['right-tackle' 'linebacker' 'defensive-line' '3-4-defensive-end'
#  '4-3-defensive-tackle' 'right-guard' 'left-guard' 'tight-end'
#  'left-tackle' '3-4-defensive-tackle' 'center' '4-3-defensive-end'
#  'long-snapper' 'punter' 'defensive-back' 'safety' 'kicker'
#  'wide-receiver' 'cornerback' 'quarterback' 'running-back' 'fullback']

# %%
import pandas as pd

# Load the data
df = pd.read_csv("football_salaries_updated.csv")

# Replace all defensive line variants with "Defensive-Line"
df["position"] = df["position"].replace(
    [
        "4-3-defensive-end",
        "4-3-defensive-tackle",
        "3-4-defensive-end",
        "3-4-defensive-tackle"
    ],
    "defensive-line"
)

# Confirm the change
print(df["position"].unique())

# (Optional) Save updated file
df.to_csv("football_salaries_positions_updated.csv", index=False)
# Out:
# ['right-tackle' 'linebacker' 'defensive-line' 'right-guard' 'left-guard'
#  'tight-end' 'left-tackle' 'center' 'long-snapper' 'punter'
#  'defensive-back' 'safety' 'kicker' 'wide-receiver' 'cornerback'
#  'quarterback' 'running-back' 'fullback']

# %%
import pandas as pd

# Load the data
df = pd.read_csv("football_salaries_positions_updated.csv")

# Replace Cornerback and Safety with Defensive-Back
df["position"] = df["position"].replace(
    ["cornerback", "safety"],
    "defensive-back"
)

# View unique positions to confirm change
print(df["position"].unique())

# (Optional) Save updated file
df.to_csv("football_salaries_cleaned_up.csv", index=False)
# Out:
# ['right-tackle' 'linebacker' 'defensive-line' 'right-guard' 'left-guard'
#  'tight-end' 'left-tackle' 'center' 'long-snapper' 'punter'
#  'defensive-back' 'kicker' 'wide-receiver' 'quarterback' 'running-back'
#  'fullback']

# %%
import pandas as pd

df = pd.read_csv("football_salaries_cleaned_up.csv")

# Count players in each position
counts = df["position"].value_counts()

print(counts)
# Out:
# position
# defensive-back    327
# defensive-line    253
# linebacker        216
# wide-receiver     193
# tight-end         111
# running-back      105
# quarterback        78
# left-tackle        64
# left-guard         59
# center             56
# right-guard        55
# right-tackle       52
# punter             32
# long-snapper       24
# kicker             24
# fullback           14
# Name: count, dtype: int64

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("football_salaries_cleaned_up.csv")

# Compute the average salary
average_salary = df["avg_year"].mean()

print("Average Salary of All Players:", average_salary)
# Out:
# Average Salary of All Players: 3256546.3680096213

# %%
import pandas as pd

df = pd.read_csv("football_salaries_cleaned_up.csv")

lowest_salary = df["avg_year"].min()

print("Lowest Salary in the File:", lowest_salary)
# Out:
# Lowest Salary in the File: 495500

# %%
import pandas as pd

df = pd.read_csv("football_salaries_cleaned_up.csv")

highest_salary = df["avg_year"].max()

print("Highest Salary in the File:", highest_salary)
# Out:
# Highest Salary in the File: 35000000

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "quarterback":
            salaries.append(float(row["avg_year"]))

average_qb_salary = sum(salaries) / len(salaries)

print("Average QB Salary:", average_qb_salary)
# Out:
# Average QB Salary: 7808317.794871795

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "wide-receiver":
            salaries.append(float(row["avg_year"]))

average_wr_salary = sum(salaries) / len(salaries)

print("Average WR Salary:", average_wr_salary)
# Out:
# Average WR Salary: 3369458.5751295337

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "defensive-back":
            salaries.append(float(row["avg_year"]))

average_db_salary = sum(salaries) / len(salaries)

print("Average DB Salary:", average_db_salary)
# Out:
# Average DB Salary: 2853252.9571865443

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "tight-end":
            salaries.append(float(row["avg_year"]))

average_te_salary = sum(salaries) / len(salaries)

print("Average TE Salary:", average_te_salary)
# Out:
# Average TE Salary: 2239550.207207207

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "running-back":
            salaries.append(float(row["avg_year"]))

average_rb_salary = sum(salaries) / len(salaries)

print("Average RB Salary:", average_rb_salary)
# Out:
# Average RB Salary: 2161938.523809524

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "defensive-line":
            salaries.append(float(row["avg_year"]))

average_DL_salary = sum(salaries) / len(salaries)

print("Average DL Salary:", average_DL_salary)
# Out:
# Average DL Salary: 3677976.2450592886

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "linebacker":
            salaries.append(float(row["avg_year"]))

average_lb_salary = sum(salaries) / len(salaries)

print("Average LB Salary:", average_lb_salary)
# Out:
# Average LB Salary: 2767210.171296296

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "left-tackle":
            salaries.append(float(row["avg_year"]))

average_lt_salary = sum(salaries) / len(salaries)

print("Average LT Salary:", average_lt_salary)
# Out:
# Average LT Salary: 4451880.71875

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "left-guard":
            salaries.append(float(row["avg_year"]))

average_lg_salary = sum(salaries) / len(salaries)

print("Average LG Salary:", average_lg_salary)
# Out:
# Average LG Salary: 3150402.9322033897

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "center":
            salaries.append(float(row["avg_year"]))

average_C_salary = sum(salaries) / len(salaries)

print("Average Center Salary:", average_C_salary)
# Out:
# Average Center Salary: 3385514.1964285714

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "right-guard":
            salaries.append(float(row["avg_year"]))

average_rg_salary = sum(salaries) / len(salaries)

print("Average RG Salary:", average_rg_salary)
# Out:
# Average RG Salary: 3759156.654545455

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "right-tackle":
            salaries.append(float(row["avg_year"]))

average_rt_salary = sum(salaries) / len(salaries)

print("Average RT Salary:", average_rt_salary)
# Out:
# Average RT Salary: 3657877.903846154

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "punter":
            salaries.append(float(row["avg_year"]))

average_p_salary = sum(salaries) / len(salaries)

print("Average Punter Salary:", average_p_salary)
# Out:
# Average Punter Salary: 1616220.15625

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "long-snapper":
            salaries.append(float(row["avg_year"]))

average_ls_salary = sum(salaries) / len(salaries)

print("Average LS Salary:", average_ls_salary)
# Out:
# Average LS Salary: 1007031.375

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "kicker":
            salaries.append(float(row["avg_year"]))

average_k_salary = sum(salaries) / len(salaries)

print("Average Kicker Salary:", average_k_salary)
# Out:
# Average Kicker Salary: 2753225.375

# %%
import csv

salaries = []

with open("football_salaries_cleaned_up.csv") as f:
    reader = csv.DictReader(f)

    for row in reader:
        if row["position"] == "fullback":
            salaries.append(float(row["avg_year"]))

average_fb_salary = sum(salaries) / len(salaries)

print("Average FB Salary:", average_fb_salary)
# Out:
# Average FB Salary: 1437013.357142857

# %%
import pandas as pd

# Load the cleaned salary data
df = pd.read_csv("football_salaries_cleaned_up.csv")

# Calculate contract length
df["contract_length"] = df["total_value"] / df["avg_year"]

# Optional: round to 2 decimal places
df["contract_length"] = df["contract_length"].round(2)

# View results
print(df[["player", "total_value", "avg_year", "contract_length"]])
# Out:
#                player  total_value  avg_year  contract_length
# 0         Trent Brown     66000000  16500000              4.0
# 1       Ja’Wuan James     51000000  12750000              4.0
# 2        Lane Johnson     56250000  11250000              5.0
# 3        Ricky Wagner     47500000   9500000              5.0
# 4      Rob Havenstein     32500000   8125000              4.0
# ...               ...          ...       ...              ...
# 1658  Trent Sherfield      1720000    573333              3.0
# 1659    Vyncint Smith      1720000    573333              3.0
# 1660  Derrick Willies      1712500    570833              3.0
# 1661      Austin Carr      1672500    557500              3.0
# 1662  Kendrick Bourne      1670000    556667              3.0
#
# [1663 rows x 4 columns]

# %%
import pandas as pd

# Load the data
df = pd.read_csv("football_salaries_cleaned_up.csv")

df["contract_length"] = df["total_value"] / df["avg_year"]

# Group by position and calculate average contract length
avg_contract_length_by_position = df.groupby("position")["contract_length"].mean()

# Optional: round for readability
avg_contract_length_by_position = avg_contract_length_by_position.round(2)

# Display results
print(avg_contract_length_by_position)
# Out:
# position
# center            3.14
# defensive-back    3.22
# defensive-line    3.24
# fullback          3.21
# kicker            3.09
# left-guard        3.22
# left-tackle       3.46
# linebacker        3.31
# long-snapper      3.50
# punter            3.44
# quarterback       2.99
# right-guard       3.15
# right-tackle      4.04
# running-back      3.10
# tight-end         3.08
# wide-receiver     3.13
# Name: contract_length, dtype: float64
